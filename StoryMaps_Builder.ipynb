# %%
# %load_ext autoreload
# %autoreload 2
from arcgis import GIS
from storymap_automation.storymap.story_builder import build_story_spec

# %%
portal_url = 'https://myutk.maps.arcgis.com/sharing/rest'

gis = GIS(portal_url, client_id='LGLkIiKiwnCO0ko2')
# Out:
# Please sign in to your GIS and paste the code that is obtained below.
# If a web browser does not automatically open, please navigate to the URL below yourself instead.
# Opening web browser to navigate to: https://myutk.maps.arcgis.com/sharing/rest/oauth2/authorize?response_type=code&client_id=LGLkIiKiwnCO0ko2&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&state=BIcsQkpEFzX7urVWtetdxrMmgCiby3&allow_verification=false

# %%
spec = build_story_spec(
    county_name='Trousdale',
    overview_text='This is an overview of Trousdale County.',
    gis=gis,
    username='mschuppe_myUTK',
    landuse_image_path='trousdale_landuse.jpg'
)
# Out:
# Building StoryMap:   0%|          | 0/11 [00:00<?, ?step/s]

# %%
from storymap_automation.storymap.story_builder import render_story_map, save_story_map
rendered_story_map = render_story_map(gis, spec, county='Trousdale', img_url='./trousdale.jpg')
story_map = save_story_map(rendered_story_map, 'Trousdale', gis, img_url='./trousdale.jpg')
# Out:
# Rendering StoryMap:   0%|          | 0/174 [00:00<?, ?step/s]
